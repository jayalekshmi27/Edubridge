# %% [markdown]
# # Titanic Analysis

# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import style

# %% [markdown]
# ## Read the file

# %%
d = pd.read_excel('C:/Users/My PC!!!/Documents/tested.xls')

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ## to rename the column

# %%
d.rename(columns={'PassengerId':'Id','SibSp':'Siblings'},inplace=True)
d
# Out:
#        Id  Survived  Pclass                                          Name  \
# 0     892         0       3                              Kelly, Mr. James
# 1     893         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0       2                     Myles, Mr. Thomas Francis
# 3     895         0       3                              Wirz, Mr. Albert
# 4     896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...     ...                                           ...
# 413  1305         0       3                            Spector, Mr. Woolf
# 414  1306         1       1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0       3                  Saether, Mr. Simon Sivertsen
# 416  1308         0       3                           Ware, Mr. Frederick
# 417  1309         0       3                      Peter, Master. Michael J
#
#         Sex   Age  Siblings  Parch              Ticket      Fare Cabin  \
# ...

# %% [markdown]
# ## to print the top 10 rows

# %%
d_top=d.head(10)
d_top
# Out:
#     Id  Survived  Pclass                                          Name  \
# 0  892         0       3                              Kelly, Mr. James
# 1  893         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2  894         0       2                     Myles, Mr. Thomas Francis
# 3  895         0       3                              Wirz, Mr. Albert
# 4  896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5  897         0       3                    Svensson, Mr. Johan Cervin
# 6  898         1       3                          Connolly, Miss. Kate
# 7  899         0       2                  Caldwell, Mr. Albert Francis
# 8  900         1       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9  901         0       3                       Davies, Mr. John Samuel
#
#       Sex   Age  Siblings  Parch     Ticket     Fare Cabin Embarked
# 0    male  34.5         0      0     330911   7.8292   NaN        Q
# ...

# %% [markdown]
# ## to print the bottom 10 rows

# %%
d_tail=d.tail(10)
d_tail
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %% [markdown]
# ## to check how many number of rows and columns

# %%
d.shape
# Out:
# (418, 12)

# %% [markdown]
# ## to check the datatypes of attributes

# %%
d.dtypes
# Out:
# Id            int64
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# Siblings      int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %% [markdown]
# ## to check the indexes

# %%
d.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %% [markdown]
# ## to print number of dimensions

# %%
d.ndim
# Out:
# 2

# %% [markdown]
# ## to print the size of dataset

# %%
d.size
# Out:
# 5016

# %% [markdown]
# ## to check the data type is empty or not

# %%
d.empty
# Out:
# False

# %% [markdown]
# ## print the column names

# %%
d.columns
# Out:
# Index(['Id', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## print the information of dataset

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        418 non-null    int64
#  1   Survived  418 non-null    int64
#  2   Pclass    418 non-null    int64
#  3   Name      418 non-null    object
#  4   Sex       418 non-null    object
#  5   Age       332 non-null    float64
#  6   Siblings  418 non-null    int64
#  7   Parch     418 non-null    int64
#  8   Ticket    418 non-null    object
#  9   Fare      417 non-null    float64
#  10  Cabin     91 non-null     object
#  11  Embarked  418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# ## print statistical information

# %%
d.describe()
# Out:
#                 Id    Survived      Pclass         Age    Siblings  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# ## To check is there any missing values

# %%
d.isna()
# Out:
#         Id  Survived  Pclass   Name    Sex    Age  Siblings  Parch  Ticket  \
# 0    False     False   False  False  False  False     False  False   False
# 1    False     False   False  False  False  False     False  False   False
# 2    False     False   False  False  False  False     False  False   False
# 3    False     False   False  False  False  False     False  False   False
# 4    False     False   False  False  False  False     False  False   False
# ..     ...       ...     ...    ...    ...    ...       ...    ...     ...
# 413  False     False   False  False  False   True     False  False   False
# 414  False     False   False  False  False  False     False  False   False
# 415  False     False   False  False  False  False     False  False   False
# 416  False     False   False  False  False   True     False  False   False
# 417  False     False   False  False  False   True     False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# ...

# %% [markdown]
# ## Sum of missing values

# %%
d.isna().sum()
# Out:
# Id            0
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age          86
# Siblings      0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %% [markdown]
# ## drop the column

# %%
d
# Out:
#        Id  Survived  Pclass                                          Name  \
# 0     892         0       3                              Kelly, Mr. James
# 1     893         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0       2                     Myles, Mr. Thomas Francis
# 3     895         0       3                              Wirz, Mr. Albert
# 4     896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...     ...                                           ...
# 413  1305         0       3                            Spector, Mr. Woolf
# 414  1306         1       1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0       3                  Saether, Mr. Simon Sivertsen
# 416  1308         0       3                           Ware, Mr. Frederick
# 417  1309         0       3                      Peter, Master. Michael J
#
#         Sex   Age  Siblings  Parch              Ticket      Fare Cabin  \
# ...

# %%
d.drop('Cabin',axis=1,inplace=True)
d
# Out:
#        Id  Survived  Pclass                                          Name  \
# 0     892         0       3                              Kelly, Mr. James
# 1     893         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0       2                     Myles, Mr. Thomas Francis
# 3     895         0       3                              Wirz, Mr. Albert
# 4     896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...     ...                                           ...
# 413  1305         0       3                            Spector, Mr. Woolf
# 414  1306         1       1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0       3                  Saether, Mr. Simon Sivertsen
# 416  1308         0       3                           Ware, Mr. Frederick
# 417  1309         0       3                      Peter, Master. Michael J
#
#         Sex   Age  Siblings  Parch              Ticket      Fare Embarked
# ...

# %% [markdown]
# ## check the duplicate value

# %%
d.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %% [markdown]
# ## sum of duplicate values

# %%
d.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## number of unique values in dataset

# %%
d.nunique()
# Out:
# Id          418
# Survived      2
# Pclass        3
# Name        418
# Sex           2
# Age          79
# Siblings      7
# Parch         8
# Ticket      363
# Fare        169
# Embarked      3
# dtype: int64

# %% [markdown]
# ## print unique names in dataset

# %%
d['Name'].unique()
# Out:
# array(['Kelly, Mr. James', 'Wilkes, Mrs. James (Ellen Needs)',
#        'Myles, Mr. Thomas Francis', 'Wirz, Mr. Albert',
#        'Hirvonen, Mrs. Alexander (Helga E Lindqvist)',
#        'Svensson, Mr. Johan Cervin', 'Connolly, Miss. Kate',
#        'Caldwell, Mr. Albert Francis',
#        'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#        'Davies, Mr. John Samuel', 'Ilieff, Mr. Ylio',
#        'Jones, Mr. Charles Cresson',
#        'Snyder, Mrs. John Pillsbury (Nelle Stevenson)',
#        'Howard, Mr. Benjamin',
#        'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)',
#        'del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
#        'Keane, Mr. Daniel', 'Assaf, Mr. Gerios',
#        'Ilmakangas, Miss. Ida Livija',
#        'Assaf Khalil, Mrs. Mariana (Miriam")"', 'Rothschild, Mr. Martin',
#        'Olsen, Master. Artur Karl',
#        'Flegenheim, Mrs. Alfred (Antoinette)',
#        'Williams, Mr. Richard Norris II',
# ...

# %% [markdown]
# ## print unique tickets in dataset

# %%
d['Ticket'].unique()
# Out:
# array([330911, 363272, 240276, 315154, 3101298, 7538, 330972, 248738,
#        2657, 'A/4 48871', 349220, 694, 21228, 24065, 'W.E.P. 5734',
#        'SC/PARIS 2167', 233734, 2692, 'STON/O2. 3101270', 2696,
#        'PC 17603', 'C 17368', 'PC 17598', 'PC 17597', 'PC 17608',
#        'A/5. 3337', 113509, 2698, 113054, 2662, 'SC/AH 3085',
#        'C.A. 31029', 'C.A. 2315', 'W./C. 6607', 13236, 2682, 342712,
#        315087, 345768, 1601, 349256, 113778, 'SOTON/O.Q. 3101263', 237249,
#        11753, 'STON/O 2. 3101291', 'PC 17594', 370374, 11813,
#        'C.A. 37671', 13695, 'SC/PARIS 2168', 29105, 19950, 'SC/A.3 2861',
#        382652, 349230, 348122, 386525, 349232, 237216, 347090, 334914,
#        'F.C.C. 13534', 330963, 113796, 2543, 382653, 349211, 3101297,
#        'PC 17562', 113503, 359306, 11770, 248744, 368702, 2678,
#        'PC 17483', 19924, 349238, 240261, 2660, 330844, 'A/4 31416',
#        364856, 29103, 347072, 345498, 'F.C. 12750', 376563, 13905, 350033,
# ...

# %% [markdown]
# ## to check the data type is empty or not

# %%
d.empty
# Out:
# False

# %% [markdown]
# ## print the count of Pclasses in dataset

# %%
d_P=d.Pclass.value_counts()
d_P
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
d_PC=pd.DataFrame(d_P)
d_PC
# Out:
#    Pclass
# 3     218
# 1     107
# 2      93

# %%
d_PC.reset_index(level=0,inplace=True)
d_PC
# Out:
#    index  Pclass
# 0      3     218
# 1      1     107
# 2      2      93

# %% [markdown]
# ## ggplot of total of passenger classes

# %%
style.use('ggplot')
x=d_PC['index']
y=d_PC['Pclass']


plt.bar(x,y,color='y',align='center')

plt.xlabel('Pclass')
plt.ylabel('Total')
plt.title('Sum of Passenger class')
plt.show()

# %% [raw]
# Most of the passengers belongs to Pclass 3

# %% [markdown]
# ## Bar graph of name &fare categorized by first 10 survived passengers

# %%
plt.style.use('seaborn-darkgrid')
x=d_top['Name']
y=d_top['Fare']
y1=d_top['Pclass']
y2=d_top['Survived']
plt.figure(figsize=(18,5))
plt.bar(x,y,label='Pclass1',color='r')
plt.bar(x,y1,label='Pclass2',bottom=y,color='b')
plt.bar(x,y2,label='Pclass3',bottom=y+y1,color='g')
plt.xlabel('NAME')
plt.ylabel('Fare')
plt.title('Name by Passenger class')
plt.legend()
plt.show()

# %% [raw]
# The highest fare is given by Caldwell, Mr. Albert Francis

# %% [markdown]
# ## Bar graph of name &fare categorized by bottom 10 survived passengers

# %%
plt.style.use('seaborn-darkgrid')
x=d_tail['Name']
y=d_tail['Fare']
y1=d_tail['Pclass']
y2=d_tail['Survived']
plt.figure(figsize=(18,5))
plt.bar(x,y,label='Pclass1',color='orange')
plt.bar(x,y1,label='Pclass2',bottom=y,color='c')
plt.bar(x,y2,label='Pclass3',bottom=y+y1,color='red')
plt.xlabel('NAME')
plt.ylabel('Fare')
plt.title('Name by Passenger class')
plt.legend()
plt.show()

# %% [raw]
# The highest fare is given by Ocana Dona

# %% [markdown]
# ## scatterplot to show Top most class with largest fare from top 10 passengers

# %%
x=d_top['Age']
y=d_top['Fare']
size=np.array([200,300,100,50,60,40,150,400,350,70])

colors=np.array(['red','orange','pink','black','blue','yellow','green','black','brown','cyan'])

plt.scatter(x,y,label='Top most class with large fare',c=colors,s=size)
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.title('scatter plot')
plt.legend()
plt.show()

# %% [markdown]
# ## scatterplot to show Top most class with largest fare from bottom 10 passengers

# %%
x=d_tail['Age']
y=d_tail['Fare']
size=np.array([200,300,100,50,60,40,150,400,350,70])

colors=np.array(['red','orange','pink','black','blue','yellow','green','black','brown','cyan'])

plt.scatter(x,y,label='Top most class with large fare',c=colors,s=size)
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.title('scatter plot')
plt.legend()
plt.show()

# %% [markdown]
# ## print the count of Gender in dataset

# %%
d_sex=d.Sex.value_counts()
d_sex
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
d_Sex=pd.DataFrame(d_sex)
d_Sex
# Out:
#         Sex
# male    266
# female  152

# %%
d_Sex.reset_index(level=0,inplace=True)
d_Sex
# Out:
#     index  Sex
# 0    male  266
# 1  female  152

# %% [markdown]
# ## ggplot of total of gender of passengers

# %%
style.use('ggplot')
x=d_Sex['index']
y=d_Sex['Sex']


plt.bar(x,y,color='Pink',align='center')

plt.xlabel('Gender')
plt.ylabel('Total')
plt.title('Sum of gender of passengers')
plt.show()

# %% [raw]
# There more male passengers than female passengers

# %% [markdown]
# ## print the count of survived in dataset

# %%
d_surv=d.Survived.value_counts()
d_surv
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
d_Surv=pd.DataFrame(d_surv)
d_Surv
# Out:
#    Survived
# 0       266
# 1       152

# %%
d_Surv.reset_index(level=0,inplace=True)
d_Surv
# Out:
#    index  Survived
# 0      0       266
# 1      1       152

# %% [markdown]
# ## ggplot of the total survivals

# %%
style.use('ggplot')
x=d_Surv['index']
y=d_Surv['Survived']


plt.bar(x,y,color='lightgreen',align='center')

plt.xlabel('survived')
plt.ylabel('Total')
plt.title('Sum of survived passengers')
plt.show()

# %% [raw]
# Out of 418 passengers only 156 survived

# %% [markdown]
# ## print the count of Embarked in dataset

# %%
d_Embarked=d.Embarked.value_counts()
d_Embarked
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
d_embark=pd.DataFrame(d_Embarked)
d_embark
# Out:
#    Embarked
# S       270
# C       102
# Q        46

# %%
d_embark.reset_index(level=0,inplace=True)
d_embark
# Out:
#   index  Embarked
# 0     S       270
# 1     C       102
# 2     Q        46

# %% [markdown]
# ## ggplot of the total embarked

# %%
style.use('ggplot')
x=d_embark['index']
y=d_embark['Embarked']


plt.bar(x,y,color='black',align='center')

plt.xlabel('Embarked')
plt.ylabel('Total')
plt.title('Sum of the embarked')
plt.show()

# %% [markdown]
# ## to show the oldest people in the dataset

# %%
d_old=d.sort_values('Age',ascending=False).head(5)
d_old
# Out:
#        Id  Survived  Pclass  \
# 96    988         1       1
# 81    973         0       1
# 236  1128         0       1
# 305  1197         1       1
# 179  1071         1       1
#
#                                                   Name     Sex   Age  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0
# 81                                  Straus, Mr. Isidor    male  67.0
# 236                           Warren, Mr. Frank Manley    male  64.0
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0
#
#      Siblings  Parch    Ticket      Fare    Cabin Embarked
# 96          1      0     19877   78.8500      C46        S
# 81          1      0  PC 17483  221.7792  C55 C57        S
# 236         1      0    110813   75.2500      D37        C
# 305         1      1    112901   26.5500      B26        S
# 179         0      2  PC 17756   83.1583      E45        C

# %% [raw]
# Cavendish, Mrs. Tyrell William (Julia Florence) is the oldest passenger in the ship

# %% [markdown]
# ## oldest passengers vs their age

# %%
plt.figure(figsize=(15,5))
ax=plt.axes()
ax.set_facecolor('cyan')
plt.barh(d_old.Name,d_old.Age,label='Age of passengers',color='y')

plt.legend()
plt.xlabel('Age')
plt.ylabel('Name of passengers')
plt.title('Oldest passengers vs their age')
plt.show()

# %% [raw]
# The oldest passenger is above 70 years old

# %%
d2=d.head(50)
d2
# Out:
#      Id  Survived  Pclass                                               Name  \
# 0   892         0       3                                   Kelly, Mr. James
# 1   893         1       3                   Wilkes, Mrs. James (Ellen Needs)
# 2   894         0       2                          Myles, Mr. Thomas Francis
# 3   895         0       3                                   Wirz, Mr. Albert
# 4   896         1       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5   897         0       3                         Svensson, Mr. Johan Cervin
# 6   898         1       3                               Connolly, Miss. Kate
# 7   899         0       2                       Caldwell, Mr. Albert Francis
# 8   900         1       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9   901         0       3                            Davies, Mr. John Samuel
# 10  902         0       3                                   Ilieff, Mr. Ylio
# ...

# %% [markdown]
# ## to show the richest people in the dataset

# %%
d_Pclass_1=d[d['Pclass']==1]
d_Pclass_1
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d_rich=d_Pclass_1.sort_values('Fare',ascending=False).head(10)
d_rich
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 53           945         1       1
# 69           961         1       1
# 64           956         0       1
# 59           951         1       1
# 375         1267         1       1
# 142         1034         0       1
# 24           916         1       1
# 184         1076         1       1
# 202         1094         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 64                         Ryerson, Master. John Borie    male  13.0      2
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# 375                           Bowen, Miss. Grace Scott  female  45.0      0
# ...

# %% [raw]
# Cardeza, Mrs. James Warburton Martinez (Charlo) is the richest passenger in the ship

# %% [markdown]
# ## bar graph of 1st class passengers with highest fares

# %%
plt.figure(figsize=(18,5))
ax=plt.axes()
ax.set_facecolor('yellow')
plt.bar(d_rich.Name,d_rich.Fare,label='Fare of passengers',color='brown',width=0.4)

plt.legend()
plt.xlabel('Fare')
plt.ylabel('Name of passengers')
plt.title('Richest passengers vs their Fare')
plt.show()

# %% [raw]
# Cardeza, Mrs. James Warburton Martinez (Charlo),the richest passenger pai a fare of greater than 500 dollars

# %% [markdown]
# ## top 300 entries

# %%
d3=d.head(300)
d3
# Out:
#        Id  Survived  Pclass                                          Name  \
# 0     892         0       3                              Kelly, Mr. James
# 1     893         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0       2                     Myles, Mr. Thomas Francis
# 3     895         0       3                              Wirz, Mr. Albert
# 4     896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...     ...                                           ...
# 295  1187         0       3                          Angheloff, Mr. Minko
# 296  1188         1       2                         Laroche, Miss. Louise
# 297  1189         0       3                             Samaan, Mr. Hanna
# 298  1190         0       1                    Loring, Mr. Joseph Holland
# 299  1191         0       3                           Johansson, Mr. Nils
#
#         Sex   Age  Siblings  Parch         Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ## lineplot of parch vs fare of male & female at the top

# %%
sns.lineplot(x='Parch',y='Fare',hue='Sex',data=d3)
plt.figure(figsize=(2,2))
plt.show()

# %% [markdown]
# ## Relational plots of parch vs age based on Pclass

# %%
sns.relplot(x='Parch',y='Age',col='Pclass',hue='Sex',data=d3)
plt.show()

# %%
d3
# Out:
#        Id  Survived  Pclass                                          Name  \
# 0     892         0       3                              Kelly, Mr. James
# 1     893         1       3              Wilkes, Mrs. James (Ellen Needs)
# 2     894         0       2                     Myles, Mr. Thomas Francis
# 3     895         0       3                              Wirz, Mr. Albert
# 4     896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...       ...     ...                                           ...
# 295  1187         0       3                          Angheloff, Mr. Minko
# 296  1188         1       2                         Laroche, Miss. Louise
# 297  1189         0       3                             Samaan, Mr. Hanna
# 298  1190         0       1                    Loring, Mr. Joseph Holland
# 299  1191         0       3                           Johansson, Mr. Nils
#
#         Sex   Age  Siblings  Parch         Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ## bottom 500 entries

# %%
d5=d.tail(500)
d5
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ## lineplot of parch vs fare of male & female at the bottom

# %%
sns.lineplot(x='Parch',y='Fare',hue='Sex',data=d5)
plt.show()

# %% [markdown]
# ## Relational plot of parch vs age of passengers at the bottom

# %%
sns.relplot(x='Parch',y='Age',col='Pclass',hue='Sex',data=d5)
plt.show()

# %% [markdown]
# ## catplot of parch vs age of passengers at the bottom

# %%
sns.catplot(x='Parch',y='Age',col='Pclass',kind='boxen',data=d5)
plt.show()

# %% [markdown]
# ## catplot of parch vs age of passengers at the top(boxen type)

# %%
sns.catplot(x='Parch',y='Age',col='Pclass',kind='boxen',data=d3)
plt.show()

# %% [markdown]
# ## top 5 richest passengers

# %%
d_rich_5=d_rich.head(5)
d_rich_5
# Out:
#        Id  Survived  Pclass  \
# 343  1235         1       1
# 53    945         1       1
# 69    961         1       1
# 64    956         0       1
# 59    951         1       1
#
#                                                   Name     Sex   Age  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0
# 53                          Fortune, Miss. Ethel Flora  female  28.0
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0
# 64                         Ryerson, Master. John Borie    male  13.0
# 59                         Chaudanson, Miss. Victorine  female  36.0
#
#      Siblings  Parch    Ticket      Fare            Cabin Embarked
# 343         0      1  PC 17755  512.3292      B51 B53 B55        C
# 53          3      2     19950  263.0000      C23 C25 C27        S
# 69          1      4     19950  263.0000      C23 C25 C27        S
# 64          2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# ...

# %% [markdown]
# ## Pie chart of Id of 5 rich  passengers vs Fare

# %%
y=d_rich_5.Id
l=d_rich_5.Fare
c=['b','y','r','g','c']

plt.pie(y,labels=y,startangle=90,shadow=True,colors=c,explode=(0,0,0,0,0.4))
plt.legend(loc='lower right')
plt.title('Id of 5 rich  passengers vs Fare')
plt.show()

# %% [raw]
# $1235 is the fare of richest passenger

# %%
d.Pclass_1_MFare=d_Pclass_1.sort_values('Fare',ascending=False)
d.Pclass_1_MFare
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 53           945         1       1
# 69           961         1       1
# 64           956         0       1
# 59           951         1       1
# ..           ...       ...     ...
# 94           986         0       1
# 205         1097         0       1
# 77           969         1       1
# 372         1264         0       1
# 266         1158         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 64                         Ryerson, Master. John Borie    male  13.0      2
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## to show the richest people who survived

# %%
d.Pclass_1_MFare_survived=d.Pclass_1_MFare.sort_values('Survived',ascending=False)
d.Pclass_1_MFare_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 411         1303         1       1
# 150         1042         1       1
# 12           904         1       1
# 374         1266         1       1
# ..           ...       ...     ...
# 308         1200         0       1
# 403         1295         0       1
# 298         1190         0       1
# 215         1107         0       1
# 266         1158         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 150              Earnshaw, Mrs. Boulton (Olive Potter)  female  23.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 374              Dodge, Mrs. Washington (Ruth Vidaver)  female  54.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Cardeza, Mrs. James Warburton Martinez (Charlo.),who is the richest person in the ship survive from the accident

# %%
d.Pclass_1_MFare_survived_only=d.Pclass_1_MFare_survived[d.Pclass_1_MFare_survived['Survived']==1]
d.Pclass_1_MFare_survived_only
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 411         1303         1       1
# 150         1042         1       1
# 12           904         1       1
# 374         1266         1       1
# 397         1289         1       1
# 96           988         1       1
# 48           940         1       1
# 350         1242         1       1
# 26           918         1       1
# 14           906         1       1
# 53           945         1       1
# 368         1260         1       1
# 402         1294         1       1
# 122         1014         1       1
# 100          992         1       1
# 364         1256         1       1
# 182         1074         1       1
# 44           936         1       1
# 92           984         1       1
# 356         1248         1       1
# 391         1283         1       1
# 22           914         1       1
# 112         1004         1       1
# 240         1132         1       1
# ...

# %%
d.Pclass_1_MFare_survived_only_10=d.Pclass_1_MFare_survived_only.head(10)
d.Pclass_1_MFare_survived_only_10
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 411         1303         1       1
# 150         1042         1       1
# 12           904         1       1
# 374         1266         1       1
# 397         1289         1       1
# 96           988         1       1
# 48           940         1       1
# 350         1242         1       1
# 26           918         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 150              Earnshaw, Mrs. Boulton (Olive Potter)  female  23.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 374              Dodge, Mrs. Washington (Ruth Vidaver)  female  54.0      1
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  female  48.0      1
# ...

# %% [markdown]
# ## Catplot of Parch vs Age

# %%
sns.catplot(x='Parch',y='Age',col='Sex',hue='Pclass',data=d3)
plt.show()

# %% [markdown]
# ## to show the youngest people in the dataset

# %%
d_young=d.sort_values('Age')
d_y=d_young.head(10)
d_y
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
# 263         1155         1       3             Klasen, Miss. Gertrud Emilia
# 117         1009         1       3          Sandstrom, Miss. Beatrice Irene
# 296         1188         1       2                    Laroche, Miss. Louise
# 89           981         0       2              Wells, Master. Ralph Lester
# 284         1176         1       3              Rosblom, Miss. Salli Helena
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %% [raw]
# Dean, Miss. Elizabeth Gladys Millvina""	 is the youngest passenger in the ship

# %%
d_y_1=d_y.head(5)
d_y_1
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
#
#         Sex   Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 354  female  0.17      1      2           C.A. 2315  20.575   NaN        S
# 201    male  0.33      0      2              347080  14.400   NaN        S
# 281    male  0.75      1      1  SOTON/O.Q. 3101315  13.775   NaN        S
# 307    male  0.83      0      1              392091   9.350   NaN        S
# 250  female  0.92      1      2          C.A. 34651  27.750   NaN        S

# %% [markdown]
# ## Bar chart of Id of 5 youngest passengers vs Age

# %%
plt.figure(figsize=(18,5))
ax=plt.axes()
ax.set_facecolor('lightgreen')
plt.bar(d_y.Name,d_y.Age,label='Age of 5 youngest passengers',color='black',width=0.4)

plt.legend()
plt.xlabel('Fare')
plt.ylabel('Name of passengers')
plt.title('Name of 5 youngest passengers vs their age')
plt.show()

# %% [raw]
# Dean, Miss. Elizabeth Gladys Millvina who is the youngest passenger in the ship is less than one year old

# %% [markdown]
# ## Barplot of Pclass vs survived

# %%
plt.figure(figsize=(5,5))
plt.title('Barplot of Pclass & survived')
sns.barplot(x='Pclass',y='Survived',data=d_young,palette='coolwarm_d')
plt.xlabel('Pclass',fontsize=15)
plt.show()

# %%
y=d_y_1.PassengerId
l=d_y_1.Age
c=['orange','black','cyan','brown','c']

plt.pie(y,labels=y,startangle=90,shadow=True,colors=c,explode=(0,0,0,0,0.4))
plt.legend(loc='lower right')
plt.title('Id of 5 youngest  passengers vs Age')
plt.show()

# %% [markdown]
# ## to show the youngest people who survived

# %%
d_young_survived=d_young[d_young['Survived']==1]
d_young_survived
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 250         1142         1       2                    West, Miss. Barbara J
# 263         1155         1       3             Klasen, Miss. Gertrud Emilia
# 117         1009         1       3          Sandstrom, Miss. Beatrice Irene
# 296         1188         1       2                    Laroche, Miss. Louise
# ..           ...       ...     ...                                      ...
# 304         1196         1       3        McCarthy, Miss. Catherine Katie""
# 365         1257         1       3           Sage, Mrs. John (Annie Bullen)
# 382         1274         1       3               Risien, Mrs. Samuel (Emma)
# 408         1300         1       3          Riordan, Miss. Johanna Hannah""
# 410         1302         1       3                   Naughton, Miss. Hannah
#
# ...

# %% [markdown]
# ## To view the record of Pclass 1

# %%
d_Pclass1=d[d['Pclass']==1]
d_Pclass1
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## To view the record of females of Pclass 1

# %%
d_Pclass1_female=d_Pclass1[d_Pclass1['Sex']=='female']
d_Pclass1_female
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 22           914         1       1
# 24           916         1       1
# 26           918         1       1
# 44           936         1       1
# 48           940         1       1
# 53           945         1       1
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 77           969         1       1
# 92           984         1       1
# 96           988         1       1
# 100          992         1       1
# 112         1004         1       1
# 114         1006         1       1
# 122         1014         1       1
# 141         1033         1       1
# 150         1042         1       1
# 156         1048         1       1
# 168         1060         1       1
# 179         1071         1       1
# 182         1074         1       1
# 184         1076         1       1
# ...

# %% [markdown]
# ## To view the record of oldest females of Pclass 1

# %%
d_Pclass1_oldfemale=d_Pclass1_female.sort_values('Age',ascending=False)
d_Pclass1_oldfemale.head(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 305         1197         1       1
# 179         1071         1       1
# 114         1006         1       1
# 48           940         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 114             Straus, Mrs. Isidor (Rosalie Ida Blun)  female  63.0      1
# 48     Bucknell, Mrs. William Robert (Emma Eliza Ward)  female  60.0      0
#
#      Parch    Ticket      Fare    Cabin Embarked
# 96       0     19877   78.8500      C46        S
# 305      1    112901   26.5500      B26        S
# 179      2  PC 17756   83.1583      E45        C
# 114      0  PC 17483  221.7792  C55 C57        S
# ...

# %% [raw]
# Cavendish, Mrs. Tyrell William (Julia Florence) is the oldest female in Pclass1

# %% [markdown]
# ## to view the records of Pclass2

# %%
d_Pclass2=d[d['Pclass']==2]
d_Pclass2
# Out:
#      PassengerId  Survived  Pclass  \
# 2            894         0       2
# 7            899         0       2
# 13           905         0       2
# 15           907         1       2
# 16           908         0       2
# ..           ...       ...     ...
# 387         1279         0       2
# 393         1285         0       2
# 401         1293         0       2
# 405         1297         0       2
# 406         1298         0       2
#
#                                               Name     Sex   Age  SibSp  \
# 2                        Myles, Mr. Thomas Francis    male  62.0      0
# 7                     Caldwell, Mr. Albert Francis    male  26.0      1
# 13                            Howard, Mr. Benjamin    male  63.0      1
# 15   del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# 16                               Keane, Mr. Daniel    male  35.0      0
# ..                                             ...     ...   ...    ...
# ...

# %% [markdown]
# ## to view the records of females Pclass2

# %%
d_Pclass2_female=d_Pclass2[d_Pclass2['Sex']=='female']
d_Pclass2_female
# Out:
#      PassengerId  Survived  Pclass  \
# 15           907         1       2
# 43           935         1       2
# 52           944         1       2
# 65           957         1       2
# 119         1011         1       2
# 120         1012         1       2
# 162         1054         1       2
# 175         1067         1       2
# 176         1068         1       2
# 178         1070         1       2
# 186         1078         1       2
# 203         1095         1       2
# 213         1105         1       2
# 220         1112         1       2
# 222         1114         1       2
# 238         1130         1       2
# 241         1133         1       2
# 246         1138         1       2
# 248         1140         1       2
# 250         1142         1       2
# 258         1150         1       2
# 262         1154         1       2
# 275         1167         1       2
# 296         1188         1       2
# 326         1218         1       2
# ...

# %% [markdown]
# ## to view the records of oldest females of Pclass2

# %%
d_Pclass2_oldfemale=d_Pclass2_female.sort_values('Age',ascending=False)
d_Pclass2_oldfemale
# Out:
#      PassengerId  Survived  Pclass  \
# 213         1105         1       2
# 330         1222         1       2
# 241         1133         1       2
# 178         1070         1       2
# 362         1254         1       2
# 349         1241         1       2
# 43           935         1       2
# 220         1112         1       2
# 119         1011         1       2
# 262         1154         1       2
# 248         1140         1       2
# 162         1054         1       2
# 15           907         1       2
# 361         1253         1       2
# 385         1277         1       2
# 222         1114         1       2
# 246         1138         1       2
# 186         1078         1       2
# 275         1167         1       2
# 176         1068         1       2
# 52           944         1       2
# 258         1150         1       2
# 238         1130         1       2
# 175         1067         1       2
# 326         1218         1       2
# ...

# %% [raw]
# Howard, Mrs. Benjamin (Ellen Truelove Arman is the oldest female in Pclass2

# %% [markdown]
# ## To view the record of Pclass 3

# %%
d_Pclass3=d[d['Pclass']==3]
d_Pclass3
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %% [markdown]
# ## To view the record of females of Pclass 3

# %%
d_Pclass3_female=d_Pclass3[d_Pclass3['Sex']=='female']
d_Pclass3_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 18           910         1       3
# ..           ...       ...     ...
# 383         1275         1       3
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 412         1304         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 6                            Connolly, Miss. Kate  female  30.0      0      0
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 18                   Ilmakangas, Miss. Ida Livija  female  27.0      1      0
# ...

# %% [markdown]
# ## To view the record of oldest females of Pclass 3

# %%
d_Pclass3_oldfemale=d_Pclass3_female.sort_values('Age',ascending=False)

# %%
d_Pclass3_oldfemale.head(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 19           911         1       3
# 309         1201         1       3
# 347         1239         1       3
# 214         1106         1       3
# 313         1205         1       3
# 153         1045         1       3
# 49           941         1       3
# 206         1098         1       3
# 32           924         1       3
# 6            898         1       3
# 359         1251         1       3
# 291         1183         1       3
# 72           964         1       3
# 412         1304         1       3
# 18           910         1       3
# 86           978         1       3
# 159         1051         1       3
# 165         1057         1       3
# 70           962         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# ...

# %% [raw]
# Wilkes, Mrs. James (Ellen Needs) is the oldest female in Pclass3

# %% [markdown]
# ## Grouping survived based on the passenger classes

# %%
Pclass_survived=d.groupby(['Pclass']).agg({'Survived':'sum'})
Pclass_survived
# Out:
#         Survived
# Pclass
# 1             50
# 2             30
# 3             72

# %%
Pclass_survived_total=Pclass_survived.sum()
Pclass_survived_total
# Out:
# Survived    152
# dtype: int64

# %% [markdown]
# ## Grouping survived based on gender in every passenger classes

# %%
Pclass_survived_gender_based=d.groupby(['Sex']).agg({'Survived':'sum'})
Pclass_survived_gender_based
# Out:
#         Survived
# Sex
# female       152
# male           0

# %% [markdown]
# ## to view those who survived have no siblings

# %%
d4=d.groupby(['Siblings']).agg({'Survived':'sum'})
d4
# Out:
#           Survived
# Siblings
# 0               88
# 1               54
# 2                6
# 3                1
# 4                1
# 5                1
# 8                1

# %%
d5=d4[:1]
d5
# Out:
#           Survived
# Siblings
# 0               88

# %% [markdown]
# ## details of those who survived have no siblings

# %%
d_nosib=d.sort_values('Siblings')
d_nosib
# Out:
#        Id  Survived  Pclass                                    Name     Sex  \
# 0     892         0       3                        Kelly, Mr. James    male
# 259  1151         0       3                Midtsjo, Mr. Karl Albert    male
# 258  1150         1       2                 Bentham, Miss. Lilian W  female
# 257  1149         0       3                   Niklasson, Mr. Samuel    male
# 256  1148         0       3                         Mahon, Mr. John    male
# ..    ...       ...     ...                                     ...     ...
# 214  1106         1       3  Andersson, Miss. Ida Augusta Margareta  female
# 55    947         0       3                    Rice, Master. Albert    male
# 140  1032         1       3             Goodwin, Miss. Jessie Allis  female
# 360  1252         0       3             Sage, Master. William Henry    male
# 188  1080         1       3                         Sage, Miss. Ada  female
#
#       Age  Siblings  Parch     Ticket     Fare Embarked
# ...

# %%
d_nosiblings=d_nosib[d_nosib['Siblings']==0]
d_nosiblings
# Out:
#        Id  Survived  Pclass                        Name     Sex   Age  \
# 0     892         0       3            Kelly, Mr. James    male  34.5
# 259  1151         0       3    Midtsjo, Mr. Karl Albert    male  21.0
# 258  1150         1       2     Bentham, Miss. Lilian W  female  19.0
# 257  1149         0       3       Niklasson, Mr. Samuel    male  28.0
# 256  1148         0       3             Mahon, Mr. John    male   NaN
# ..    ...       ...     ...                         ...     ...   ...
# 71    963         0       3          Minkoff, Mr. Lazar    male  21.0
# 11    903         0       1  Jones, Mr. Charles Cresson    male  46.0
# 10    902         0       3            Ilieff, Mr. Ylio    male   NaN
# 138  1030         1       3       Drapkin, Miss. Jennie  female  23.0
# 47    939         0       3    Shaughnessy, Mr. Patrick    male   NaN
#
#      Siblings  Parch           Ticket     Fare Embarked
# 0           0      0           330911   7.8292        Q
# ...

# %% [markdown]
# ## check the relationship between data

# %%
d.corr()
# Out:
#                 Id  Survived    Pclass       Age  Siblings     Parch      Fare
# Id        1.000000 -0.023245 -0.026751 -0.034102  0.003818  0.043080  0.008211
# Survived -0.023245  1.000000 -0.108615 -0.000013  0.099943  0.159120  0.191514
# Pclass   -0.026751 -0.108615  1.000000 -0.492143  0.001087  0.018721 -0.577147
# Age      -0.034102 -0.000013 -0.492143  1.000000 -0.091587 -0.061249  0.337932
# Siblings  0.003818  0.099943  0.001087 -0.091587  1.000000  0.306895  0.171539
# Parch     0.043080  0.159120  0.018721 -0.061249  0.306895  1.000000  0.230046
# Fare      0.008211  0.191514 -0.577147  0.337932  0.171539  0.230046  1.000000

# %% [markdown]
# ## to print random data

# %%
d.sample(5)
# Out:
#        Id  Survived  Pclass                        Name   Sex   Age  Siblings  \
# 366  1258         0       3           Caram, Mr. Joseph  male   NaN         1
# 16    908         0       2           Keane, Mr. Daniel  male  35.0         0
# 308  1200         0       1  Hays, Mr. Charles Melville  male  55.0         1
# 187  1079         0       3          Davies, Mr. Joseph  male  17.0         2
# 370  1262         0       2            Giles, Mr. Edgar  male  21.0         1
#
#      Parch     Ticket     Fare Embarked
# 366      0       2689  14.4583        C
# 16       0     233734  12.3500        Q
# 308      1      12749  93.5000        S
# 187      0  A/4 48873   8.0500        S
# 370      0      28133  11.5000        S

# %% [markdown]
# # print the record on which equal no of siblings and parents abroad

# %%
d[d.Siblings==d.Parch]
# Out:
#        Id  Survived  Pclass                                          Name  \
# 0     892         0       3                              Kelly, Mr. James
# 2     894         0       2                     Myles, Mr. Thomas Francis
# 3     895         0       3                              Wirz, Mr. Albert
# 4     896         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5     897         0       3                    Svensson, Mr. Johan Cervin
# ..    ...       ...     ...                                           ...
# 413  1305         0       3                            Spector, Mr. Woolf
# 414  1306         1       1                  Oliva y Ocana, Dona. Fermina
# 415  1307         0       3                  Saether, Mr. Simon Sivertsen
# 416  1308         0       3                           Ware, Mr. Frederick
# 417  1309         0       3                      Peter, Master. Michael J
#
#         Sex   Age  Siblings  Parch              Ticket      Fare Embarked
# ...

# %% [markdown]
# ## plot a graph-Pclass vs survived

# %%
plt.bar(d['Pclass'],d['Fare'])
plt.title('Pclass vs Fare',fontsize=15,color='red')
plt.xlabel('Pclass',fontsize=15)
plt.ylabel('Fare',fontsize=15)
plt.grid(True)
plt.show()

# %%
d6=d_Pclass3_oldfemale.head(5)
d6
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 19           911         1       3
# 309         1201         1       3
# 347         1239         1       3
# 214         1106         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 19             Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
# 309       Hansen, Mrs. Claus Peter (Jennie L Howard)  female  45.0      1
# 347  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0      0
# 214           Andersson, Miss. Ida Augusta Margareta  female  38.0      4
#
#      Parch  Ticket     Fare Cabin Embarked
# 1        0  363272   7.0000   NaN        S
# 19       0    2696   7.2250   NaN        C
# 309      0  350026  14.1083   NaN        S
# 347      0    2688   7.2292   NaN        C
# 214      2  347091   7.7750   NaN        S

# %%
plt.figure(figsize=(18,5))
plt.barh(d6['Age'],d6['Name'])
plt.title('Name vs Age of oldest females',fontsize=15,color='red')
plt.ylabel('Age',fontsize=15)
plt.xlabel('Name',fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# ## kdeplot of age density

# %%
sns.kdeplot(d['Age'],color='red',shade=True)
plt.show()

# %% [markdown]
# ## kde plot of ticket fare density

# %%
sns.kdeplot(d['Fare'],color='blue',shade=True)
plt.show()

# %% [markdown]
# ## kde plot of fare vs age

# %%
sns.kdeplot(d['Fare'],d['Age'],color='red',shade=True)
plt.show()

# %% [markdown]
# ## kde plot of Passenger class vs fare

# %%
sns.kdeplot(d['Fare'],d['Pclass'],color='green',vertical='Truesns',shade=True)
plt.show()

# %%
sns.pairplot(d,diag_kind='kde',hue='Sex')
plt.show()

# %% [markdown]
# ## pairplot of Pclass

# %%
sns.pairplot(d,diag_kind='kde',hue='Pclass')
plt.show()

# %% [markdown]
# ## pairplot of Pclass with hue as age

# %%
sns.pairplot(d[d.Age.isin([2,4,6])],
             hue='Age',
             vars=['Parch','Survived', 'Pclass'],
             palette='husl'
            )
plt.show()

# %% [markdown]
# ## distplot of age of passengers

# %%
plt.figure(figsize=(8,5))
sns.distplot(d.Age,
            bins=20,
            kde_kws={'lw':8, 'color':'pink'},
            hist_kws={'alpha':0.3,'color':'yellow'}
            )

plt.xlabel('age',fontsize=16, labelpad=15)
plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.distplot(d.Fare,
            bins=20,
            kde_kws={'lw':8, 'color':'orange'},
            hist_kws={'alpha':0.3,'color':'cyan'}
            )

plt.xlabel('age',fontsize=16, labelpad=15)
plt.yticks([])
plt.show()

# %% [markdown]
# ## violin plot of fare

# %%
sns.violinplot(x=d.Fare,color='pink')
plt.show()

# %% [markdown]
# ## violin plot of age of passengers

# %%
sns.violinplot(x=d.Age,volor='violet')
plt.show()

# %% [markdown]
# ## Heat map of data

# %%
sns.heatmap(d.corr(),cmap='RdPu',annot=True,center=0)
plt.show()

# %% [markdown]
# I have worked on TITANIC DATASET which includes 12 columns and 418 observations. From my analysis I have found that in my data,
#
# 1.There are more male passengers than female passengers
#
# 2.There are more dead passengers than those who sruvived
#
# 3.I found the Richest Passenger(),his fare(),his gender,whether he survived or not
#
# 4.I found the Yougest Passenger(),his age,whether he survived or not
#
# 5.I found the oldest female passenger of the ship
#
# 6.I found the youngest passengers who didn't have siblings and also with their parents abroad
#
# 7.I found the records of all the female passengers of Pclass 1,2 and 3
#
# 8.I found density of fare,age etc using kdeplot
#
# 9.All the statistical information regarding the dataset analysed and plotted
