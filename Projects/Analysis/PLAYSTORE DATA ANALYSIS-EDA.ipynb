# %% [markdown]
# # PLAY STORE DATA ANALYSIS

# %% [markdown]
# ## importing libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import style
import seaborn as sns

# %% [markdown]
# ## reading the file

# %%
r= pd.read_excel('C:/Users/My PC!!!/Documents/playstoredata.xls')

# %%
r
# Out:
#                                                      App            Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN
# 1                                    Coloring book moana      ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...      ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint      ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book      ART_AND_DESIGN
# ...                                                  ...                 ...
# 10834                                        FP VoiceBot              FAMILY
# 10835                                    Fast Tract Diet  HEALTH_AND_FITNESS
# 10836                            Trine 2: Complete Story                GAME
# 10837                                       sugar, sugar              FAMILY
# 10838                               Word Search Tab 1 FR              FAMILY
#
# ...

# %% [markdown]
# ## to rename the column

# %%
r.rename(columns={'Price':'App price'},inplace=True)
r
# Out:
#                                                      App            Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN
# 1                                    Coloring book moana      ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...      ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint      ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book      ART_AND_DESIGN
# ...                                                  ...                 ...
# 10834                                        FP VoiceBot              FAMILY
# 10835                                    Fast Tract Diet  HEALTH_AND_FITNESS
# 10836                            Trine 2: Complete Story                GAME
# 10837                                       sugar, sugar              FAMILY
# 10838                               Word Search Tab 1 FR              FAMILY
#
# ...

# %% [markdown]
#  ## to print the top 10 rows

# %%
r1=r.head(300)
r1
# Out:
#                                                    App        Category  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                  Coloring book moana  ART_AND_DESIGN
# 2    U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN
# 3                                Sketch - Draw & Paint  ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ..                                                 ...             ...
# 295  GANMA! - All original stories free of charge f...          COMICS
# 296                         RÃ¶hrich Werner Soundboard          COMICS
# 297                    Unicorn Pokez - Color By Number          COMICS
# 298                   MangaToon - Comics updated Daily          COMICS
# 299             Manga Net â€“ Best Online Manga Reader          COMICS
#
#      Rating  Reviews Size  Installs  Type  App price Content Rating  \
# ...

# %% [markdown]
# ## to print the bottom 10 rows

# %%
r2=r.tail(10)
r2
# Out:
#                                App            Category  Rating  Reviews  \
# 10829  Circle Colors Pack-FN Theme     PERSONALIZATION     4.2        6
# 10830                   Solitaire+                GAME     4.6    11235
# 10831          Fruit Ninja Classic                GAME     4.3    85468
# 10832                     FO Bixby     PERSONALIZATION     5.0        5
# 10833                      Mu.F.O.                GAME     5.0        2
# 10834                  FP VoiceBot              FAMILY     NaN       17
# 10835              Fast Tract Diet  HEALTH_AND_FITNESS     4.4       35
# 10836      Trine 2: Complete Story                GAME     3.8      252
# 10837                 sugar, sugar              FAMILY     4.2     1405
# 10838         Word Search Tab 1 FR              FAMILY     NaN        0
#
#         Size  Installs  Type  App price Content Rating            Genres  \
# 10829    89k        50  Paid       0.99       Everyone   Personalization
# ...

# %% [markdown]
# ## to check how many number of rows and columns

# %%
r.shape
# Out:
# (10839, 13)

# %% [markdown]
# ## to check the datatypes of attributes

# %%
r.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# ## to check the indexes

# %%
r.index
# Out:
# RangeIndex(start=0, stop=10839, step=1)

# %% [markdown]
# ## to print number of dimensions

# %%
r.ndim
# Out:
# 2

# %% [markdown]
# ## to print the size of dataset

# %%
r.size
# Out:
# 140907

# %% [markdown]
# ## to check the data type is empty or not

# %%
r.empty
# Out:
# False

# %% [markdown]
# ## print the column names

# %%
r.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'App price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# ## print the information of dataset

# %%
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10838 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10839 non-null  int64
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  int64
#  6   Type            10839 non-null  object
#  7   App price       10839 non-null  float64
#  8   Content Rating  10839 non-null  object
#  9   Genres          10839 non-null  object
#  10  Last Updated    10839 non-null  object
#  11  Current Ver     10831 non-null  object
#  12  Android Ver     10837 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# ## print statistical information

# %%
r.describe()
# Out:
#             Rating       Reviews      Installs     App price
# count  9366.000000  1.083900e+04  1.083900e+04  10839.000000
# mean      4.191757  4.441939e+05  1.546577e+07      1.027463
# std       0.515219  2.927893e+06  8.503315e+07     15.950436
# min       1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01  3.000000e+03      0.000000
# 50%       4.300000  2.094000e+03  1.000000e+05      0.000000
# 75%       4.500000  5.478300e+04  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  1.000000e+09    400.000000

# %% [markdown]
# ## To check is there any missing values

# %%
r.isna()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  App price  \
# 0      False     False   False    False  False     False  False      False
# 1      False     False   False    False  False     False  False      False
# 2      False     False   False    False  False     False  False      False
# 3      False     False   False    False  False     False  False      False
# 4      False     False   False    False  False     False  False      False
# ...      ...       ...     ...      ...    ...       ...    ...        ...
# 10834  False     False    True    False  False     False  False      False
# 10835  False     False   False    False  False     False  False      False
# 10836  False     False   False    False  False     False  False      False
# 10837  False     False   False    False  False     False  False      False
# 10838  False     False    True    False  False     False  False      False
#
# ...

# %% [markdown]
# ## Sum of missing values

# %%
r.isna().sum()
# Out:
# App                  1
# Category             0
# Rating            1473
# Reviews              0
# Size                 0
# Installs             0
# Type                 0
# App price            0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# ## check the duplicate value

# %%
r.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10834    False
# 10835    False
# 10836    False
# 10837    False
# 10838    False
# Length: 10839, dtype: bool

# %% [markdown]
# ## sum of duplicate values

# %%
r.duplicated().sum()
# Out:
# 483

# %% [markdown]
# ## number of unique values in dataset

# %%
r.nunique()
# Out:
# App               9657
# Category            33
# Rating              39
# Reviews           6001
# Size               460
# Installs            20
# Type                 2
# App price           92
# Content Rating       6
# Genres             119
# Last Updated      1377
# Current Ver       2783
# Android Ver         33
# dtype: int64

# %% [markdown]
# ## print unique in dataset

# %%
r['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %% [markdown]
# ## print the count of Type in dataset

# %%
r.Type.value_counts()
# Out:
# Free    10039
# Paid      800
# Name: Type, dtype: int64

# %% [markdown]
# ## print the count of Category in dataset

# %%
r.Category.value_counts()
# Out:
# FAMILY                 1971
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# COMICS                   60
# PARENTING                60
# BEAUTY                   53
# ...

# %% [markdown]
# ## to view the count of category

# %%
r.Category.value_counts().head(10)
# Out:
# FAMILY             1971
# GAME               1144
# TOOLS               843
# MEDICAL             463
# BUSINESS            460
# PRODUCTIVITY        424
# PERSONALIZATION     392
# COMMUNICATION       387
# SPORTS              384
# LIFESTYLE           382
# Name: Category, dtype: int64

# %% [raw]
# The most number of apps belongs to category 'family'

# %% [markdown]
# ## print the count of Genres in dataset

# %%
r.Genres.value_counts()
# Out:
# Tools                       842
# Entertainment               623
# Education                   549
# Medical                     463
# Business                    460
#                            ...
# Adventure;Brain Games         1
# Communication;Creativity      1
# Parenting;Brain Games         1
# Board;Pretend Play            1
# Strategy;Creativity           1
# Name: Genres, Length: 119, dtype: int64

# %% [raw]
# Most of the apps belongs to the gender 'Tools'

# %% [markdown]
# ## to show the highest paid apps

# %%
m_paid_apps=r.sort_values('App price',ascending=False).head(10)
m_paid_apps
# Out:
#                                   App   Category  Rating  Reviews  Size  \
# 10254        I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7.3
# 10253                   ðŸ’Ž I'm rich  LIFESTYLE     3.8      718    26
# 10393                       I am Rich    FINANCE     4.3      180   3.8
# 10389                   I Am Rich Pro     FAMILY     4.4      201   2.7
# 10386              I am rich(premium)    FINANCE     3.5      472  965k
# 10385                      I am Rich!    FINANCE     3.8       93    22
# 10390  I am rich (Most expensive app)    FINANCE     4.1      129   2.7
# 10381                  I am Rich Plus     FAMILY     4.0      856   8.7
# 10380                       I am rich  LIFESTYLE     3.8     3547   1.8
# 10383               I Am Rich Premium    FINANCE     4.1     1867   4.7
#
#        Installs  Type  App price Content Rating         Genres  \
# 10254     10000  Paid     400.00       Everyone      Lifestyle
# ...

# %%
paid_apps=m_paid_apps.head(5)
paid_apps
# Out:
#                             App   Category  Rating  Reviews  Size  Installs  \
# 10254  I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7.3     10000
# 10253             ðŸ’Ž I'm rich  LIFESTYLE     3.8      718    26     10000
# 10393                 I am Rich    FINANCE     4.3      180   3.8      5000
# 10389             I Am Rich Pro     FAMILY     4.4      201   2.7      5000
# 10386        I am rich(premium)    FINANCE     3.5      472  965k      5000
#
#        Type  App price Content Rating         Genres         Last Updated  \
# 10254  Paid     400.00       Everyone      Lifestyle  2018-05-03 00:00:00
# 10253  Paid     399.99       Everyone      Lifestyle  2018-03-11 00:00:00
# 10393  Paid     399.99       Everyone        Finance  2018-03-22 00:00:00
# 10389  Paid     399.99       Everyone  Entertainment  2017-05-30 00:00:00
# 10386  Paid     399.99       Everyone        Finance  2017-05-01 00:00:00
#
#       Current Ver Android Ver
# 10254       1.0.1  4.1 and up
# ...

# %% [raw]
# The top most paid app is I'm Rich - Trump Edition

# %% [markdown]
# ## most paid apps vs their price

# %%
plt.barh(m_paid_apps['App'],m_paid_apps['App price'],color='black')
plt.title('Most paid apps vs their price',fontsize=15,color='red')
ax=plt.axes()
ax.set_facecolor('cyan')
plt.ylabel('Apps',fontsize=15)
plt.xlabel('App price',fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Bar graph of most paid apps vs Installs

# %%
plt.barh(m_paid_apps['App'],m_paid_apps['Installs'])
plt.title('Most paid apps vs their installs',fontsize=15,color='red')
ax=plt.axes()
ax.set_facecolor('orange')
plt.ylabel('Apps',fontsize=15)
plt.xlabel('Installs',fontsize=15)
plt.grid(True)
plt.show()

# %% [raw]
# Among the most paid apps Iam rich is the most installed one

# %% [markdown]
# ## to show the most rated apps

# %%
m_rated_apps=r.sort_values('Rating',ascending=False)
rated_apps=m_rated_apps.head(10)
rated_apps
# Out:
#                                                      App         Category  \
# 7795                                        D-H Pharmacy        LIFESTYLE
# 9826                          Trinity Church Deltona, FL        LIFESTYLE
# 10618                                       Morse Player           FAMILY
# 8788                      EK Bailey Preaching Conference           EVENTS
# 9873                                                  FN         BUSINESS
# 10620  30WPM Amateur ham radio Koch CW Morse code tra...           FAMILY
# 9870                                Wallpapers FN SCAR H  PERSONALIZATION
# 2276                                        Sway Medical          MEDICAL
# 2294                                      Labs on Demand          MEDICAL
# 2297          Dermatology Atlas (Colored & Illustrative)          MEDICAL
#
#        Rating  Reviews Size  Installs  Type  App price Content Rating  \
# 7795      5.0        6  2.3      1000  Free       0.00       Everyone
# ...

# %% [raw]
# There are  more than 10 most rated apps and their rating is 5.0

# %%
plt.bar(rated_apps['App'],rated_apps['Size'])
plt.title('Most rated apps vs their size',fontsize=15,color='red')
ax=plt.axes()
ax.set_facecolor('yellow')
plt.xticks(rotation=70)
plt.ylabel('Apps',fontsize=15)
plt.xlabel('Size',fontsize=15)
plt.grid(True)
plt.show()

# %% [raw]
# Among the most rated apps 'Ek Bailey Preaching Conference' app has the largest size

# %% [markdown]
# ## bar graph of Most rated apps vs their reviews

# %%
plt.barh(m_rated_apps['App'],m_rated_apps['Reviews'])
plt.title('Most rated apps vs their reviews',fontsize=15,color='red')
ax=plt.axes()
ax.set_facecolor('yellow')
plt.ylabel('Apps',fontsize=15)
plt.xlabel('Installs',fontsize=15)
plt.grid(True)
plt.show()

# %% [raw]
# Among the most rated app Trinity Church Deltona app has the highest reviews

# %% [markdown]
# ## to view the free apps in the data

# %%
r.free_apps=r[r['Type']=='Free']
r.free_apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10034                                   Sya9a Maroc - FR               FAMILY
# 10035                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10036                             Parkinson Exercices FR              MEDICAL
# 10037                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10038      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## to find  category of top rated free apps

# %%
r.top_free_apps=r.free_apps.sort_values('Rating',ascending=False).head(10)
r.top_free_apps
# Out:
#                                                    App             Category  \
# 4930                           AJ Rafael Music Lessons               FAMILY
# 628                            Online Girls Chat Group               DATING
# 7514                         Cy-Fair VFD EMS Protocols              MEDICAL
# 7516                          Cy-Fair Christian Church            LIFESTYLE
# 7553                                           CZ-Help  BOOKS_AND_REFERENCE
# 7563                                         CZ Kompas                TOOLS
# 7625                                           DB HOME            LIFESTYLE
# 5642                                       Movement BE               SOCIAL
# 7629                                        DB Pickles             BUSINESS
# 7652  Superheroes, Marvel, DC, Comics, TV, Movies News               COMICS
#
#       Rating  Reviews Size  Installs  Type  App price Content Rating  \
# ...

# %%
r1.top_free_apps=r.top_free_apps.head(5)
r1.top_free_apps
# Out:
#                             App             Category  Rating  Reviews Size  \
# 4930    AJ Rafael Music Lessons               FAMILY     5.0        1  8.2
# 628     Online Girls Chat Group               DATING     5.0        5    5
# 7514  Cy-Fair VFD EMS Protocols              MEDICAL     5.0        2   20
# 7516   Cy-Fair Christian Church            LIFESTYLE     5.0        2  9.3
# 7553                    CZ-Help  BOOKS_AND_REFERENCE     5.0        2  1.4
#
#       Installs  Type  App price Content Rating             Genres  \
# 4930        10  Free        0.0       Everyone      Entertainment
# 628        100  Free        0.0     Mature 17+             Dating
# 7514       100  Free        0.0   Everyone 10+            Medical
# 7516       100  Free        0.0       Everyone          Lifestyle
# 7553         5  Free        0.0       Everyone  Books & Reference
#
#              Last Updated Current Ver   Android Ver
# 4930  2017-11-29 00:00:00       1.2.1    4.1 and up
# ...

# %%
y=r1.top_free_apps.Reviews
l=r1.top_free_apps.Category
c=['b','y','r','g','c']

plt.pie(y,labels=l,startangle=90,shadow=True,colors=c,explode=(0,0,0,0,0.4))
plt.legend(loc='lower right')
plt.title('5 Free Apps:their category & reviews')
plt.show()

# %% [markdown]
# ## top 20 highest rated apps and its types

# %%
m1_rated_apps=m_rated_apps.head(20)
m1_rated_apps
# Out:
#                                                      App         Category  \
# 7795                                        D-H Pharmacy        LIFESTYLE
# 9826                          Trinity Church Deltona, FL        LIFESTYLE
# 10618                                       Morse Player           FAMILY
# 8788                      EK Bailey Preaching Conference           EVENTS
# 9873                                                  FN         BUSINESS
# 10620  30WPM Amateur ham radio Koch CW Morse code tra...           FAMILY
# 9870                                Wallpapers FN SCAR H  PERSONALIZATION
# 2276                                        Sway Medical          MEDICAL
# 2294                                      Labs on Demand          MEDICAL
# 2297          Dermatology Atlas (Colored & Illustrative)          MEDICAL
# 2299                                     Tablet Reminder          MEDICAL
# 2301                                    Galaxies of Hope          MEDICAL
# ...

# %% [raw]
# The top rated app D-H pharmacy is a free app

# %% [markdown]
# ## stripplot of App vs Category of most rated apps

# %%
sns.set_style('whitegrid')
plt.xticks(rotation=70)
sns.stripplot(x='Category',y='App',hue='Type',jitter=0.5,dodge=True,data=m1_rated_apps)
plt.show()

# %% [markdown]
# ## Total of all categories of various apps

# %%
app_cat=r.groupby('Category').Installs.sum().sort_values(ascending=False)
app_cat_top=app_cat.head(10)
app_cat_top
# Out:
# Category
# GAME                  35086024415
# COMMUNICATION         32647276251
# PRODUCTIVITY          14176091369
# SOCIAL                14069867902
# TOOLS                 11452771915
# FAMILY                10258263505
# PHOTOGRAPHY           10088247655
# NEWS_AND_MAGAZINES     7496317760
# TRAVEL_AND_LOCAL       6868887146
# VIDEO_PLAYERS          6222002720
# Name: Installs, dtype: int64

# %%
apps_cat_top=pd.DataFrame(app_cat_top)
apps_cat_top
# Out:
#                        Installs
# Category
# GAME                35086024415
# COMMUNICATION       32647276251
# PRODUCTIVITY        14176091369
# SOCIAL              14069867902
# TOOLS               11452771915
# FAMILY              10258263505
# PHOTOGRAPHY         10088247655
# NEWS_AND_MAGAZINES   7496317760
# TRAVEL_AND_LOCAL     6868887146
# VIDEO_PLAYERS        6222002720

# %%
apps_cat_top.reset_index(level=0,inplace=True)
apps_cat_top
# Out:
#              Category     Installs
# 0                GAME  35086024415
# 1       COMMUNICATION  32647276251
# 2        PRODUCTIVITY  14176091369
# 3              SOCIAL  14069867902
# 4               TOOLS  11452771915
# 5              FAMILY  10258263505
# 6         PHOTOGRAPHY  10088247655
# 7  NEWS_AND_MAGAZINES   7496317760
# 8    TRAVEL_AND_LOCAL   6868887146
# 9       VIDEO_PLAYERS   6222002720

# %% [markdown]
# ## Bar graph of Category vs Installs on basis of categories of best apps

# %%
plt.figure(figsize=(5,5))
ax=plt.axes()
ax.set_facecolor('cyan')

plt.bar(apps_cat_top.Category,apps_cat_top.Installs,label='total installs',color='r',width=0.5)
plt.xticks(rotation=70)

plt.legend()
plt.xlabel('Category')
plt.ylabel('Installs')
plt.title('Top 10 most Installed apps')
plt.show()

# %% [markdown]
# ## top 10 most installe apps

# %%
r.top_Installed_apps=r.sort_values('Installs',ascending=False).head(10)
r.top_Installed_apps
# Out:
#                      App            Category  Rating   Reviews Size  \
# 1839      Subway Surfers                GAME     4.5  27725352   76
# 2702       Google Photos         PHOTOGRAPHY     4.5  10858538    0
# 446                Gmail       COMMUNICATION     4.3   4604483    0
# 3732      Subway Surfers                GAME     4.5  27711703   76
# 1726      Subway Surfers                GAME     4.5  27724094   76
# 3601         Google News  NEWS_AND_MAGAZINES     3.9    877635   13
# 3740  WhatsApp Messenger       COMMUNICATION     4.4  69109672    0
# 1884      Subway Surfers                GAME     4.5  27725352   76
# 3745           Instagram              SOCIAL     4.5  66509917    0
# 3402        Google Drive        PRODUCTIVITY     4.4   2731211    0
#
#         Installs  Type  Price Content Rating            Genres  \
# 1839  1000000000  Free    0.0   Everyone 10+            Arcade
# 2702  1000000000  Free    0.0       Everyone       Photography
# ...

# %% [markdown]
# ## 10 most underrated apps

# %%
u_rated_apps=r.sort_values('Rating')
u1_rated_apps=u_rated_apps.head(5)
u1_rated_apps
# Out:
#                                                     App Category  Rating  \
# 9809   Lottery Ticket Checker - Florida Results & Lotto    TOOLS     1.0
# 10449                     Truck Driving Test Class 3 BC   FAMILY     1.0
# 8163                                     DS Creator 2.0    TOOLS     1.0
# 4825                                      Clarksburg AH  MEDICAL     1.0
# 10219                                 Speech Therapy: F   FAMILY     1.0
#
#        Reviews Size  Installs  Type  App price Content Rating     Genres  \
# 9809         3   41       500  Free       0.00       Everyone      Tools
# 10449        1    2        50  Paid       1.49       Everyone  Education
# 8163         2  4.4       500  Free       0.00       Everyone      Tools
# 4825         1   28        50  Free       0.00       Everyone    Medical
# 10219        1   16        10  Paid       2.99       Everyone  Education
#
#               Last Updated   Current Ver   Android Ver
# ...

# %% [raw]
# There are more than 10 most installed apps and most of them belongs to the category 'FAmily'

# %% [markdown]
# ## the unique values of genres

# %%
r['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Art & Design;Action & Adventure',
#        'Auto & Vehicles', 'Beauty', 'Books & Reference', 'Business',
#        'Comics', 'Comics;Creativity', 'Communication', 'Dating',
#        'Education;Education', 'Education', 'Education;Creativity',
#        'Education;Music & Video', 'Education;Action & Adventure',
#        'Education;Pretend Play', 'Education;Brain Games', 'Entertainment',
#        'Entertainment;Music & Video', 'Entertainment;Brain Games',
#        'Entertainment;Creativity', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play',
#        'Adventure;Action & Adventure', 'Arcade', 'Casual', 'Card',
#        'Casual;Pretend Play', 'Action', 'Strategy', 'Puzzle', 'Sports',
#        'Music', 'Word', 'Racing', 'Casual;Creativity',
# ...

# %% [markdown]
# ## Reviews and Category of most rated app

# %%
y=m1_rated_apps.Reviews
l=m1_rated_apps.Category
c=['r','b','g','k','y']

plt.pie(y,labels=l,startangle=90,shadow=True,colors=c,explode=(0,0,0,0.4,0))
plt.legend(loc='lower right')
plt.title('Most Rated Apps')
plt.show()

# %% [markdown]
# ## Reviews and Category of most under rated app

# %%
y=u1_rated_apps.Reviews
l=u1_rated_apps.Category
c=['b','y','r','g','c']

plt.pie(y,labels=l,startangle=90,shadow=True,colors=c,explode=(0,0,0,0,0.4))
plt.legend(loc='lower right')
plt.title('Most Under Rated Apps')
plt.show()

# %% [markdown]
# ## stripplot of size vs Rating of top 100 data

# %%
sns.set_style('whitegrid')
sns.stripplot(x='Size',y='Rating',data=r1)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# ## lineplot of bottom 300 random apps

# %%
sns.lineplot(x='Rating',y='App price',hue='Category',data=r2)
plt.show()

# %% [markdown]
# ## correlation of the dataset

# %%
r.corr()
# Out:
#              Rating   Reviews  Installs  App price
# Rating     1.000000  0.068141  0.051355  -0.021903
# Reviews    0.068141  1.000000  0.643121  -0.009668
# Installs   0.051355  0.643121  1.000000  -0.011691
# App price -0.021903 -0.009668 -0.011691   1.000000

# %% [markdown]
# ## Heat map of the dataset

# %%
sns.heatmap(r.corr(),cmap='viridis',vmin=0,vmax=1)
plt.show()

# %% [markdown]
# ## top 100 most entertaining apps based on their installs

# %%
r_Entertainment=r[r['Genres']=='Entertainment']
r1_Entertainment=r_Entertainment.sort_values('Installs',ascending=False).head(100)
r1_Entertainment
# Out:
#                                                     App       Category  \
# 849                                   Google Play Games  ENTERTAINMENT
# 5462                                  Google Play Games         FAMILY
# 839                                             Netflix  ENTERTAINMENT
# 858                                      Talking Angela  ENTERTAINMENT
# 915                                             Netflix  ENTERTAINMENT
# ...                                                 ...            ...
# 3998                                               H TV         FAMILY
# 4399                     Grand Theft Auto V: The Manual         FAMILY
# 3893  Eventbrite - Discover popular events & nearby fun         FAMILY
# 859                                            DStv Now  ENTERTAINMENT
# 854                                                H TV  ENTERTAINMENT
#
#       Rating  Reviews Size    Installs  Type  App price Content Rating  \
# ...

# %% [markdown]
# ## lineplot of 100 most entertaining apps

# %%
sns.lineplot(x='Rating',y='Category',hue='Content Rating',data=r1_Entertainment)
plt.show()

# %%
sns.scatterplot(x='App',y='Rating',style='Content Rating',data=r1_Entertainment)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ## catplot of top 100 data

# %%
sns.catplot(x='Installs',y='Rating',hue='Content Rating',kind='boxen',data=r1)
plt.show()

# %% [markdown]
# ## catplot of bottom 300 apps

# %%
sns.catplot(x='Installs',y='Rating',hue='Content Rating',col='Type',kind='boxen',data=r3)
plt.show()

# %%
r3=r.tail(100)
r3
# Out:
#                                               App            Category  Rating  \
# 10739                    EG Classroom Decimalsâ„¢              FAMILY     3.0
# 10740                    EG | Explore Folegandros    TRAVEL_AND_LOCAL     NaN
# 10741  Inventory & Barcode scanner & WIFI scanner        PRODUCTIVITY     4.6
# 10742                          Vital Tones EI Pro  HEALTH_AND_FITNESS     NaN
# 10743              Silence Premium Do Not Disturb               TOOLS     4.5
# ...                                           ...                 ...     ...
# 10834                                 FP VoiceBot              FAMILY     NaN
# 10835                             Fast Tract Diet  HEALTH_AND_FITNESS     4.4
# 10836                     Trine 2: Complete Story                GAME     3.8
# 10837                                sugar, sugar              FAMILY     4.2
# 10838                        Word Search Tab 1 FR              FAMILY     NaN
#
# ...

# %%
sns.catplot(x='Installs',y='Rating',hue='Content Rating',col='Type',kind='point',data=r3)
plt.show()

# %% [markdown]
# ## catplot of bottom 100 apps of point type

# %%
sns.catplot(x='Installs',y='Rating',hue='Content Rating',col='Type',kind='point',data=r1)
plt.show()

# %%
r4=r.tail(300)
r4
# Out:
#                                              App            Category  Rating  \
# 10539                              PAC-MAN CE DX                GAME     4.5
# 10540             Theatre of the Absurd CE(Full)              FAMILY     4.1
# 10541  TI-84 CE Graphing Calculator Manual TI 84              FAMILY     5.0
# 10542                         AC CE BJT Actorial              FAMILY     NaN
# 10543               Depths of Betrayal CE (Full)              FAMILY     4.3
# ...                                          ...                 ...     ...
# 10834                                FP VoiceBot              FAMILY     NaN
# 10835                            Fast Tract Diet  HEALTH_AND_FITNESS     4.4
# 10836                    Trine 2: Complete Story                GAME     3.8
# 10837                               sugar, sugar              FAMILY     4.2
# 10838                       Word Search Tab 1 FR              FAMILY     NaN
#
# ...

# %% [markdown]
# ## Box plot of Rating of random apps

# %%
sns.boxplot(r4.Rating)
plt.show()

# %% [markdown]
# ## Box plot of Rating with Content Rating

# %%
sns.boxplot(x=r4.Type,y=r4.Rating,hue=r4['Content Rating'],width=0.7)
plt.show()

# %% [markdown]
# ## Distplot of Rating of random app

# %%
sns.distplot(r4.Rating,color='red')
plt.show()

# %% [markdown]
# ## Distplot of Installs of random app

# %%
plt.figure(figsize=(8,5))
sns.distplot(r4.Installs,
            bins=20,
            kde_kws={'lw':8, 'color':'xkcd:black'},
            hist_kws={'alpha':0.3,'color':'red'}
            )

plt.xlabel('Installs',fontsize=16, labelpad=15)
plt.yticks([])
plt.show()

# %% [markdown]
# ## Distplot of Ratings of random app

# %%
plt.figure(figsize=(8,5))
sns.distplot(r4.Rating,
            bins=20,
            kde_kws={'lw':8, 'color':'xkcd:bluish green'},
            hist_kws={'alpha':0.3,'color':'yellow'}
            )

plt.xlabel('Ratings',fontsize=16, labelpad=15)
plt.yticks([])
plt.show()

# %%
plt.figure(figsize=(16,18))
sns.relplot(x='App',y="Rating",hue='Type',data=r4)
plt.show()

# %%
sns.set()

# %% [markdown]
# ## Countplot of Types of apps in the dataset

# %%
sns.countplot(x='Type',data=r,palette='colorblind')
plt.show()

# %% [raw]
# There more number of free apps compare to paid apps

# %% [markdown]
# ## Pie chart showing percentage of total contents

# %%
plt.title('Content Rating',fontsize=20)
r4['Content Rating'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ## count plot of Installs of various apps

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Installs',data=r,palette='tab10')
plt.show()

# %% [markdown]
# ## Plotting Installs against ratings by grouping the type of apps

# %%
r.groupby('Type')[['Installs','Rating']].sum().plot.bar(color=['red','blue'],figsize=(8,5))
plt.ylabel('type:free & paid')
plt.show()

# %%
r6=r.tail(10)
r6
# Out:
#                                App            Category  Rating  Reviews  \
# 10829  Circle Colors Pack-FN Theme     PERSONALIZATION     4.2        6
# 10830                   Solitaire+                GAME     4.6    11235
# 10831          Fruit Ninja Classic                GAME     4.3    85468
# 10832                     FO Bixby     PERSONALIZATION     5.0        5
# 10833                      Mu.F.O.                GAME     5.0        2
# 10834                  FP VoiceBot              FAMILY     NaN       17
# 10835              Fast Tract Diet  HEALTH_AND_FITNESS     4.4       35
# 10836      Trine 2: Complete Story                GAME     3.8      252
# 10837                 sugar, sugar              FAMILY     4.2     1405
# 10838         Word Search Tab 1 FR              FAMILY     NaN        0
#
#         Size  Installs  Type  App price Content Rating            Genres  \
# 10829    89k        50  Paid       0.99       Everyone   Personalization
# ...

# %% [markdown]
# ## Grouping apps based on rating and app price

# %%
r6.groupby('App')[['Rating','App price']].sum().plot.bar(color=['red','blue'],figsize=(8,5))
plt.ylabel('type:free & paid')
plt.show()

# %% [markdown]
# ## pie chart of total install of apps

# %%
plt.figure(figsize=(5,12))
plt.title('Installs',fontsize=20)
r4['Installs'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.title('genres')
sns.barplot(x='App',y='Rating',data=r6,hue='Content Rating',palette='tab10')
plt.xlabel('Installs',fontsize=7)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ## bar plot of Genres vs rating of most paid apps

# %%
plt.figure(figsize=(5,5))
plt.title('genres')
sns.barplot(x='Genres',y='Rating',data=m_paid_apps,palette='coolwarm_r')
plt.xlabel('Genres',fontsize=15)
plt.show()

# %% [raw]
# The most popular genres is entertainment

# %%
r['Android Ver'].value_counts()
# Out:
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1361
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 1.0 and up               2
# 5.0 - 8.0                2
# 4.0.3 - 7.1.1            2
# 5.0 - 6.0                1
# 7.0 - 7.1.1              1
# 5.0 - 7.1.1              1
# 2.2 - 7.1.1              1
# 4.1 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %% [markdown]
# ## count plot of most paid apps base on their android version

# %%
plt.figure(figsize=(8,6))
sns.countplot(x=m_paid_apps['Android Ver'],data=m_paid_apps,palette='rocket_r',order=m_paid_apps['Android Ver'].value_counts().index)
plt.xlabel('App',fontsize=25)
plt.xticks(rotation=70)
plt.show()

# %% [raw]
# Most of the apps are of 4 and above version

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# We have worked on PLAYSTORE DATASET which includes 13 columns and 10839 observations.
# From our analysis we have found that in our data,
#
# 1.There are more free apps compared to paid apps.(Free:10039,Paid:800)
#
# 2.Free apps are installed the most compared to paid apps
#
# 3.We found that most of the apps are of Android version 4.4 an above
#
# 4.We found that the most popular genres is 'Entertainment
#
# 5.We found that most of the apps is suitable for everyone
#
# 6.We found the density of installs,Ratings
#
# 7.We found that there are more than 10 most rated apps,most-under rated apps,most_installed apps,most-reviewed apps
#
# 8.We found all the statistical informations and correlation of the data
